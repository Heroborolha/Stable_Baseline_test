# %%
from stable_baselines3.common.env_util import make_atari_env
from stable_baselines3.common.vec_env import VecFrameStack
from stable_baselines3 import A2C
import ale_py

vec_env = make_atari_env("PongNoFrameskip-v4", n_envs=4, seed=0)
vec_env = VecFrameStack(vec_env, n_stack=4)

model = A2C("CnnPolicy", vec_env, verbose=1)
model.learn(total_timesteps=25_000)

obs = vec_env.reset()
while True:
    action, _states = model.predict(obs, deterministic=False)
    obs, reward, dones, info = vec_env.step(action)
    vec_env.render("human")
# Out:
# Using cpu device
# Wrapping the env in a VecTransposeImage.
# ------------------------------------
# | time/                 |          |
# |    fps                | 405      |
# |    iterations         | 100      |
# |    time_elapsed       | 4        |
# |    total_timesteps    | 2000     |
# | train/                |          |
# |    entropy_loss       | -1.74    |
# |    explained_variance | -0.017   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 99       |
# |    policy_loss        | 0.028    |
# |    value_loss         | 0.000328 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.16e+03 |
# |    ep_rew_mean        | -20.8    |
# | time/                 |          |
# |    fps                | 481      |
# |    iterations         | 200      |
# |    time_elapsed       | 8        |
# |    total_timesteps    | 4000     |
# | train/                |          |
# |    entropy_loss       | -1.77    |
# |    explained_variance | 0.00197  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 199      |
# |    policy_loss        | -0.602   |
# |    value_loss         | 0.364    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.16e+03 |
# |    ep_rew_mean        | -20.8    |
# | time/                 |          |
# |    fps                | 515      |
# |    iterations         | 300      |
# |    time_elapsed       | 11       |
# |    total_timesteps    | 6000     |
# | train/                |          |
# |    entropy_loss       | -1.76    |
# |    explained_variance | 0.00138  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 299      |
# |    policy_loss        | -0.0213  |
# |    value_loss         | 0.0459   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.24e+03 |
# |    ep_rew_mean        | -20.8    |
# | time/                 |          |
# |    fps                | 531      |
# |    iterations         | 400      |
# |    time_elapsed       | 15       |
# |    total_timesteps    | 8000     |
# | train/                |          |
# |    entropy_loss       | -1.77    |
# |    explained_variance | 0.0755   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 399      |
# |    policy_loss        | 0.052    |
# |    value_loss         | 0.000993 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.27e+03 |
# |    ep_rew_mean        | -20.8    |
# | time/                 |          |
# |    fps                | 543      |
# |    iterations         | 500      |
# |    time_elapsed       | 18       |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -1.78    |
# |    explained_variance | 0.00676  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 499      |
# |    policy_loss        | -0.22    |
# |    value_loss         | 0.137    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.39e+03 |
# |    ep_rew_mean        | -20.6    |
# | time/                 |          |
# |    fps                | 550      |
# |    iterations         | 600      |
# |    time_elapsed       | 21       |
# |    total_timesteps    | 12000    |
# | train/                |          |
# |    entropy_loss       | -1.73    |
# |    explained_variance | -0.0214  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 599      |
# |    policy_loss        | 0.0843   |
# |    value_loss         | 0.00239  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.35e+03 |
# |    ep_rew_mean        | -20.7    |
# | time/                 |          |
# |    fps                | 556      |
# |    iterations         | 700      |
# |    time_elapsed       | 25       |
# |    total_timesteps    | 14000    |
# | train/                |          |
# |    entropy_loss       | -1.78    |
# |    explained_variance | 0.00677  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 699      |
# |    policy_loss        | -0.272   |
# |    value_loss         | 0.18     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.35e+03 |
# |    ep_rew_mean        | -20.7    |
# | time/                 |          |
# |    fps                | 562      |
# |    iterations         | 800      |
# |    time_elapsed       | 28       |
# |    total_timesteps    | 16000    |
# | train/                |          |
# |    entropy_loss       | -1.78    |
# |    explained_variance | -0.117   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 799      |
# |    policy_loss        | 0.0571   |
# |    value_loss         | 0.00134  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.42e+03 |
# |    ep_rew_mean        | -20.7    |
# | time/                 |          |
# |    fps                | 565      |
# |    iterations         | 900      |
# |    time_elapsed       | 31       |
# |    total_timesteps    | 18000    |
# | train/                |          |
# |    entropy_loss       | -1.78    |
# |    explained_variance | -0.0516  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 899      |
# |    policy_loss        | 0.0406   |
# |    value_loss         | 0.000666 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.42e+03 |
# |    ep_rew_mean        | -20.7    |
# | time/                 |          |
# |    fps                | 569      |
# |    iterations         | 1000     |
# |    time_elapsed       | 35       |
# |    total_timesteps    | 20000    |
# | train/                |          |
# |    entropy_loss       | -1.79    |
# |    explained_variance | -0.423   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 999      |
# |    policy_loss        | 0.0834   |
# |    value_loss         | 0.00279  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.47e+03 |
# |    ep_rew_mean        | -20.8    |
# | time/                 |          |
# |    fps                | 572      |
# |    iterations         | 1100     |
# |    time_elapsed       | 38       |
# |    total_timesteps    | 22000    |
# | train/                |          |
# |    entropy_loss       | -1.78    |
# |    explained_variance | 0.117    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1099     |
# |    policy_loss        | -0.351   |
# |    value_loss         | 0.217    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.46e+03 |
# |    ep_rew_mean        | -20.8    |
# | time/                 |          |
# |    fps                | 574      |
# |    iterations         | 1200     |
# |    time_elapsed       | 41       |
# |    total_timesteps    | 24000    |
# | train/                |          |
# |    entropy_loss       | -1.79    |
# |    explained_variance | 0.523    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1199     |
# |    policy_loss        | 0.0311   |
# |    value_loss         | 0.00106  |
# ------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 16
#      14 action, _states = model.predict(obs, deterministic=False)
#      15 obs, reward, dones, info = vec_env.step(action)
# ---> 16 vec_env.render("human")
#
# File d:\Users\Jordan\anaconda3\lib\site-packages\stable_baselines3\common\vec_env\base_vec_env.py:389, in VecEnvWrapper.render(self, mode)
#     388 def render(self, mode: Optional[str] = None) -> Optional[np.ndarray]:
# --> 389     return self.venv.render(mode=mode)
#
# File d:\Users\Jordan\anaconda3\lib\site-packages\stable_baselines3\common\vec_env\dummy_vec_env.py:103, in DummyVecEnv.render(self, mode)
#      96 def render(self, mode: Optional[str] = None) -> Optional[np.ndarray]:
#      97     """
#      98     Gym environment rendering. If there are multiple environments then
#      99     they are tiled together in one image via ``BaseVecEnv.render()``.
#     100
#     101     :param mode: The rendering type.
#     102     """
# --> 103     return super().render(mode=mode)
#
# File d:\Users\Jordan\anaconda3\lib\site-packages\stable_baselines3\common\vec_env\base_vec_env.py:264, in VecEnv.render(self, mode)
#     261     import cv2
#     263     cv2.imshow("vecenv", bigimg[:, :, ::-1])
# --> 264     cv2.waitKey(1)
#     265 else:
#     266     return bigimg
#
# KeyboardInterrupt:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
