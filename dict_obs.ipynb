# %%
from stable_baselines3 import PPO
from stable_baselines3.common.envs import SimpleMultiObsEnv

env = SimpleMultiObsEnv(random_start=False)
model = PPO("MultiInputPolicy", env, verbose=1)
model.learn(total_timesteps=100_000)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env in a VecTransposeImage.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 55       |
# |    ep_rew_mean     | -4.55    |
# | time/              |          |
# |    fps             | 1055     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 2048     |
# ---------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 44.8       |
# |    ep_rew_mean          | -3.46      |
# | time/                   |            |
# |    fps                  | 554        |
# |    iterations           | 2          |
# |    time_elapsed         | 7          |
# |    total_timesteps      | 4096       |
# | train/                  |            |
# |    approx_kl            | 0.01866027 |
# |    clip_fraction        | 0.263      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.37      |
# |    explained_variance   | -0.0443    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0749     |
# |    n_updates            | 10         |
# |    policy_gradient_loss | -0.0288    |
# |    value_loss           | 0.273      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 26.1        |
# |    ep_rew_mean          | -1.52       |
# | time/                   |             |
# |    fps                  | 483         |
# |    iterations           | 3           |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.014701302 |
# |    clip_fraction        | 0.271       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.32       |
# |    explained_variance   | 0.22        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.221       |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0352     |
# |    value_loss           | 0.602       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 17.2       |
# |    ep_rew_mean          | -0.622     |
# | time/                   |            |
# |    fps                  | 450        |
# |    iterations           | 4          |
# |    time_elapsed         | 18         |
# |    total_timesteps      | 8192       |
# | train/                  |            |
# |    approx_kl            | 0.01681761 |
# |    clip_fraction        | 0.322      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.27      |
# |    explained_variance   | 0.424      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.253      |
# |    n_updates            | 30         |
# |    policy_gradient_loss | -0.0413    |
# |    value_loss           | 0.469      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 12.9        |
# |    ep_rew_mean          | -0.195      |
# | time/                   |             |
# |    fps                  | 432         |
# |    iterations           | 5           |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.020059556 |
# |    clip_fraction        | 0.47        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.16       |
# |    explained_variance   | 0.436       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.152       |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0531     |
# |    value_loss           | 0.355       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 9.48       |
# |    ep_rew_mean          | 0.152      |
# | time/                   |            |
# |    fps                  | 422        |
# |    iterations           | 6          |
# |    time_elapsed         | 29         |
# |    total_timesteps      | 12288      |
# | train/                  |            |
# |    approx_kl            | 0.02450019 |
# |    clip_fraction        | 0.467      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.03      |
# |    explained_variance   | 0.477      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0298     |
# |    n_updates            | 50         |
# |    policy_gradient_loss | -0.0571    |
# |    value_loss           | 0.186      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.19        |
# |    ep_rew_mean          | 0.281       |
# | time/                   |             |
# |    fps                  | 415         |
# |    iterations           | 7           |
# |    time_elapsed         | 34          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.031131374 |
# |    clip_fraction        | 0.378       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.839      |
# |    explained_variance   | 0.556       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0323     |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0572     |
# |    value_loss           | 0.0609      |
# -----------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 6.71     |
# |    ep_rew_mean          | 0.429    |
# | time/                   |          |
# |    fps                  | 410      |
# |    iterations           | 8        |
# |    time_elapsed         | 39       |
# |    total_timesteps      | 16384    |
# | train/                  |          |
# |    approx_kl            | 0.067154 |
# |    clip_fraction        | 0.359    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -0.567   |
# |    explained_variance   | 0.722    |
# |    learning_rate        | 0.0003   |
# |    loss                 | -0.0498  |
# |    n_updates            | 70       |
# |    policy_gradient_loss | -0.0572  |
# |    value_loss           | 0.0248   |
# --------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.31        |
# |    ep_rew_mean          | 0.469       |
# | time/                   |             |
# |    fps                  | 405         |
# |    iterations           | 9           |
# |    time_elapsed         | 45          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.030304458 |
# |    clip_fraction        | 0.117       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.412      |
# |    explained_variance   | 0.731       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.053      |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0298     |
# |    value_loss           | 0.00811     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.31        |
# |    ep_rew_mean          | 0.469       |
# | time/                   |             |
# |    fps                  | 401         |
# |    iterations           | 10          |
# |    time_elapsed         | 50          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.008439681 |
# |    clip_fraction        | 0.0888      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.286      |
# |    explained_variance   | 0.914       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0166     |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0189     |
# |    value_loss           | 0.00331     |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 6.13      |
# |    ep_rew_mean          | 0.487     |
# | time/                   |           |
# |    fps                  | 399       |
# |    iterations           | 11        |
# |    time_elapsed         | 56        |
# |    total_timesteps      | 22528     |
# | train/                  |           |
# |    approx_kl            | 0.0389806 |
# |    clip_fraction        | 0.0786    |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.206    |
# |    explained_variance   | 0.919     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0206   |
# |    n_updates            | 100       |
# |    policy_gradient_loss | -0.0204   |
# |    value_loss           | 0.00345   |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.07        |
# |    ep_rew_mean          | 0.493       |
# | time/                   |             |
# |    fps                  | 396         |
# |    iterations           | 12          |
# |    time_elapsed         | 61          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.012323694 |
# |    clip_fraction        | 0.0625      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.154      |
# |    explained_variance   | 0.972       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.000167    |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.01       |
# |    value_loss           | 0.0012      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6.03         |
# |    ep_rew_mean          | 0.497        |
# | time/                   |              |
# |    fps                  | 394          |
# |    iterations           | 13           |
# |    time_elapsed         | 67           |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0039952477 |
# |    clip_fraction        | 0.0449       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.143       |
# |    explained_variance   | 0.975        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.012       |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.0125      |
# |    value_loss           | 0.000802     |
# ------------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 24.1      |
# |    ep_rew_mean          | -1.51     |
# | time/                   |           |
# |    fps                  | 392       |
# |    iterations           | 14        |
# |    time_elapsed         | 73        |
# |    total_timesteps      | 28672     |
# | train/                  |           |
# |    approx_kl            | 1.3800001 |
# |    clip_fraction        | 0.243     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.138    |
# |    explained_variance   | 0.993     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.032    |
# |    n_updates            | 130       |
# |    policy_gradient_loss | -0.0318   |
# |    value_loss           | 0.000372  |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 41.2        |
# |    ep_rew_mean          | -3.42       |
# | time/                   |             |
# |    fps                  | 390         |
# |    iterations           | 15          |
# |    time_elapsed         | 78          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.021179069 |
# |    clip_fraction        | 0.138       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.23       |
# |    explained_variance   | -0.0161     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0866      |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0125     |
# |    value_loss           | 0.215       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 21.2        |
# |    ep_rew_mean          | -1.2        |
# | time/                   |             |
# |    fps                  | 389         |
# |    iterations           | 16          |
# |    time_elapsed         | 84          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.010967213 |
# |    clip_fraction        | 0.0829      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.531      |
# |    explained_variance   | 0.585       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0942      |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0118     |
# |    value_loss           | 0.217       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.03        |
# |    ep_rew_mean          | 0.497       |
# | time/                   |             |
# |    fps                  | 389         |
# |    iterations           | 17          |
# |    time_elapsed         | 89          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.015952567 |
# |    clip_fraction        | 0.0785      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.511      |
# |    explained_variance   | 0.835       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.194       |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0144     |
# |    value_loss           | 0.196       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.02        |
# |    ep_rew_mean          | 0.498       |
# | time/                   |             |
# |    fps                  | 389         |
# |    iterations           | 18          |
# |    time_elapsed         | 94          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.001461455 |
# |    clip_fraction        | 0.0223      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.15       |
# |    explained_variance   | 0.926       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00407    |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.000527   |
# |    value_loss           | 0.066       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6.04         |
# |    ep_rew_mean          | 0.496        |
# | time/                   |              |
# |    fps                  | 388          |
# |    iterations           | 19           |
# |    time_elapsed         | 100          |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0040039117 |
# |    clip_fraction        | 0.023        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0634      |
# |    explained_variance   | 0.977        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0324      |
# |    n_updates            | 180          |
# |    policy_gradient_loss | 0.000128     |
# |    value_loss           | 0.00567      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.95        |
# |    ep_rew_mean          | 0.394       |
# | time/                   |             |
# |    fps                  | 388         |
# |    iterations           | 20          |
# |    time_elapsed         | 105         |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.003976477 |
# |    clip_fraction        | 0.00522     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0188     |
# |    explained_variance   | 0.987       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00127    |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.00543    |
# |    value_loss           | 0.000293    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 6.01       |
# |    ep_rew_mean          | 0.499      |
# | time/                   |            |
# |    fps                  | 388        |
# |    iterations           | 21         |
# |    time_elapsed         | 110        |
# |    total_timesteps      | 43008      |
# | train/                  |            |
# |    approx_kl            | 0.00864605 |
# |    clip_fraction        | 0.0639     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.11      |
# |    explained_variance   | 0.976      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0516    |
# |    n_updates            | 200        |
# |    policy_gradient_loss | -0.0209    |
# |    value_loss           | 0.0436     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 10.9       |
# |    ep_rew_mean          | 0.014      |
# | time/                   |            |
# |    fps                  | 387        |
# |    iterations           | 22         |
# |    time_elapsed         | 116        |
# |    total_timesteps      | 45056      |
# | train/                  |            |
# |    approx_kl            | 0.09007062 |
# |    clip_fraction        | 0.0641     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.0805    |
# |    explained_variance   | 0.994      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0728    |
# |    n_updates            | 210        |
# |    policy_gradient_loss | -0.0132    |
# |    value_loss           | 0.000176   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.61        |
# |    ep_rew_mean          | 0.239       |
# | time/                   |             |
# |    fps                  | 387         |
# |    iterations           | 23          |
# |    time_elapsed         | 121         |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.017018022 |
# |    clip_fraction        | 0.368       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.585      |
# |    explained_variance   | 0.137       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0238      |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.0504     |
# |    value_loss           | 0.13        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.7         |
# |    ep_rew_mean          | 0.33        |
# | time/                   |             |
# |    fps                  | 387         |
# |    iterations           | 24          |
# |    time_elapsed         | 126         |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.026372569 |
# |    clip_fraction        | 0.366       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.421      |
# |    explained_variance   | 0.391       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0048     |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.0503     |
# |    value_loss           | 0.0798      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.56        |
# |    ep_rew_mean          | 0.444       |
# | time/                   |             |
# |    fps                  | 387         |
# |    iterations           | 25          |
# |    time_elapsed         | 132         |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.028196823 |
# |    clip_fraction        | 0.332       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.293      |
# |    explained_variance   | 0.702       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00416    |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0388     |
# |    value_loss           | 0.0854      |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 6.15      |
# |    ep_rew_mean          | 0.485     |
# | time/                   |           |
# |    fps                  | 386       |
# |    iterations           | 26        |
# |    time_elapsed         | 137       |
# |    total_timesteps      | 53248     |
# | train/                  |           |
# |    approx_kl            | 0.0421914 |
# |    clip_fraction        | 0.192     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.105    |
# |    explained_variance   | 0.781     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0445   |
# |    n_updates            | 250       |
# |    policy_gradient_loss | -0.0356   |
# |    value_loss           | 0.0118    |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.01        |
# |    ep_rew_mean          | 0.499       |
# | time/                   |             |
# |    fps                  | 386         |
# |    iterations           | 27          |
# |    time_elapsed         | 142         |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.057762332 |
# |    clip_fraction        | 0.0183      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0213     |
# |    explained_variance   | 0.934       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0233     |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.0151     |
# |    value_loss           | 0.0024      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.02        |
# |    ep_rew_mean          | 0.498       |
# | time/                   |             |
# |    fps                  | 386         |
# |    iterations           | 28          |
# |    time_elapsed         | 148         |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.005649533 |
# |    clip_fraction        | 0.0364      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0533     |
# |    explained_variance   | 0.917       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0302     |
# |    n_updates            | 270         |
# |    policy_gradient_loss | 0.0174      |
# |    value_loss           | 0.0131      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6            |
# |    ep_rew_mean          | 0.5          |
# | time/                   |              |
# |    fps                  | 386          |
# |    iterations           | 29           |
# |    time_elapsed         | 153          |
# |    total_timesteps      | 59392        |
# | train/                  |              |
# |    approx_kl            | 0.0001721289 |
# |    clip_fraction        | 0.00186      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.00792     |
# |    explained_variance   | 0.992        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -4.72e-05    |
# |    n_updates            | 280          |
# |    policy_gradient_loss | -0.00244     |
# |    value_loss           | 0.000255     |
# ------------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 25       |
# |    ep_rew_mean          | -1.62    |
# | time/                   |          |
# |    fps                  | 386      |
# |    iterations           | 30       |
# |    time_elapsed         | 158      |
# |    total_timesteps      | 61440    |
# | train/                  |          |
# |    approx_kl            | 4.282115 |
# |    clip_fraction        | 0.349    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -0.00787 |
# |    explained_variance   | 0.999    |
# |    learning_rate        | 0.0003   |
# |    loss                 | -0.0751  |
# |    n_updates            | 290      |
# |    policy_gradient_loss | -0.0461  |
# |    value_loss           | 7.45e-05 |
# --------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 42.2        |
# |    ep_rew_mean          | -3.54       |
# | time/                   |             |
# |    fps                  | 386         |
# |    iterations           | 31          |
# |    time_elapsed         | 164         |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.009850645 |
# |    clip_fraction        | 0.0676      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.737      |
# |    explained_variance   | -1.75       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00597     |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.0125     |
# |    value_loss           | 0.0764      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 14.1        |
# |    ep_rew_mean          | -0.396      |
# | time/                   |             |
# |    fps                  | 386         |
# |    iterations           | 32          |
# |    time_elapsed         | 169         |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.045355298 |
# |    clip_fraction        | 0.23        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.784      |
# |    explained_variance   | 0.655       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.387       |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.0111     |
# |    value_loss           | 0.37        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 6.33       |
# |    ep_rew_mean          | 0.467      |
# | time/                   |            |
# |    fps                  | 387        |
# |    iterations           | 33         |
# |    time_elapsed         | 174        |
# |    total_timesteps      | 67584      |
# | train/                  |            |
# |    approx_kl            | 0.01899137 |
# |    clip_fraction        | 0.125      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.618     |
# |    explained_variance   | 0.935      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.521      |
# |    n_updates            | 320        |
# |    policy_gradient_loss | -0.0158    |
# |    value_loss           | 0.425      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.5         |
# |    ep_rew_mean          | 0.45        |
# | time/                   |             |
# |    fps                  | 387         |
# |    iterations           | 34          |
# |    time_elapsed         | 179         |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.053378526 |
# |    clip_fraction        | 0.146       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.261      |
# |    explained_variance   | 0.952       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.415       |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.0139     |
# |    value_loss           | 0.295       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 6.01       |
# |    ep_rew_mean          | 0.499      |
# | time/                   |            |
# |    fps                  | 387        |
# |    iterations           | 35         |
# |    time_elapsed         | 185        |
# |    total_timesteps      | 71680      |
# | train/                  |            |
# |    approx_kl            | 0.11931392 |
# |    clip_fraction        | 0.205      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.0358    |
# |    explained_variance   | 0.827      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0276    |
# |    n_updates            | 340        |
# |    policy_gradient_loss | -0.025     |
# |    value_loss           | 0.00562    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.02        |
# |    ep_rew_mean          | 0.498       |
# | time/                   |             |
# |    fps                  | 386         |
# |    iterations           | 36          |
# |    time_elapsed         | 190         |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.004315397 |
# |    clip_fraction        | 0.00273     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.00765    |
# |    explained_variance   | 0.981       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00291    |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.00552    |
# |    value_loss           | 0.000217    |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 11.1      |
# |    ep_rew_mean          | -0.005    |
# | time/                   |           |
# |    fps                  | 387       |
# |    iterations           | 37        |
# |    time_elapsed         | 195       |
# |    total_timesteps      | 75776     |
# | train/                  |           |
# |    approx_kl            | 0.0708254 |
# |    clip_fraction        | 0.0782    |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.0845   |
# |    explained_variance   | 0.998     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0579   |
# |    n_updates            | 360       |
# |    policy_gradient_loss | -0.0127   |
# |    value_loss           | 0.000296  |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.38        |
# |    ep_rew_mean          | 0.262       |
# | time/                   |             |
# |    fps                  | 387         |
# |    iterations           | 38          |
# |    time_elapsed         | 201         |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.012995366 |
# |    clip_fraction        | 0.334       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.467      |
# |    explained_variance   | 0.212       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00236    |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.0488     |
# |    value_loss           | 0.117       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 7.1        |
# |    ep_rew_mean          | 0.39       |
# | time/                   |            |
# |    fps                  | 387        |
# |    iterations           | 39         |
# |    time_elapsed         | 206        |
# |    total_timesteps      | 79872      |
# | train/                  |            |
# |    approx_kl            | 0.03532343 |
# |    clip_fraction        | 0.366      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.314     |
# |    explained_variance   | 0.371      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0208    |
# |    n_updates            | 380        |
# |    policy_gradient_loss | -0.0526    |
# |    value_loss           | 0.0744     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 6.21       |
# |    ep_rew_mean          | 0.479      |
# | time/                   |            |
# |    fps                  | 387        |
# |    iterations           | 40         |
# |    time_elapsed         | 211        |
# |    total_timesteps      | 81920      |
# | train/                  |            |
# |    approx_kl            | 0.06580491 |
# |    clip_fraction        | 0.205      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.12      |
# |    explained_variance   | 0.585      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0252    |
# |    n_updates            | 390        |
# |    policy_gradient_loss | -0.0347    |
# |    value_loss           | 0.0274     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.09        |
# |    ep_rew_mean          | 0.491       |
# | time/                   |             |
# |    fps                  | 386         |
# |    iterations           | 41          |
# |    time_elapsed         | 217         |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.012816146 |
# |    clip_fraction        | 0.0213      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0682     |
# |    explained_variance   | 0.923       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0106     |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.0125     |
# |    value_loss           | 0.00327     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6           |
# |    ep_rew_mean          | 0.5         |
# | time/                   |             |
# |    fps                  | 386         |
# |    iterations           | 42          |
# |    time_elapsed         | 222         |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.039241433 |
# |    clip_fraction        | 0.0114      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0168     |
# |    explained_variance   | 0.95        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00188     |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.0109     |
# |    value_loss           | 0.00197     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.71        |
# |    ep_rew_mean          | 0.229       |
# | time/                   |             |
# |    fps                  | 386         |
# |    iterations           | 43          |
# |    time_elapsed         | 227         |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.052542977 |
# |    clip_fraction        | 0.255       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.263      |
# |    explained_variance   | 0.996       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0938     |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.0621     |
# |    value_loss           | 0.000123    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 7.78       |
# |    ep_rew_mean          | 0.322      |
# | time/                   |            |
# |    fps                  | 386        |
# |    iterations           | 44         |
# |    time_elapsed         | 232        |
# |    total_timesteps      | 90112      |
# | train/                  |            |
# |    approx_kl            | 0.01529934 |
# |    clip_fraction        | 0.349      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.42      |
# |    explained_variance   | 0.404      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0377    |
# |    n_updates            | 430        |
# |    policy_gradient_loss | -0.0516    |
# |    value_loss           | 0.0543     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 6.47       |
# |    ep_rew_mean          | 0.453      |
# | time/                   |            |
# |    fps                  | 386        |
# |    iterations           | 45         |
# |    time_elapsed         | 238        |
# |    total_timesteps      | 92160      |
# | train/                  |            |
# |    approx_kl            | 0.05554559 |
# |    clip_fraction        | 0.355      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.256     |
# |    explained_variance   | 0.442      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0308    |
# |    n_updates            | 440        |
# |    policy_gradient_loss | -0.0524    |
# |    value_loss           | 0.0493     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 6.07       |
# |    ep_rew_mean          | 0.493      |
# | time/                   |            |
# |    fps                  | 387        |
# |    iterations           | 46         |
# |    time_elapsed         | 243        |
# |    total_timesteps      | 94208      |
# | train/                  |            |
# |    approx_kl            | 0.19822618 |
# |    clip_fraction        | 0.154      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.0608    |
# |    explained_variance   | 0.857      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0315    |
# |    n_updates            | 450        |
# |    policy_gradient_loss | -0.0317    |
# |    value_loss           | 0.00718    |
# ----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 6             |
# |    ep_rew_mean          | 0.5           |
# | time/                   |               |
# |    fps                  | 387           |
# |    iterations           | 47            |
# |    time_elapsed         | 248           |
# |    total_timesteps      | 96256         |
# | train/                  |               |
# |    approx_kl            | 0.00021472655 |
# |    clip_fraction        | 0.00376       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0139       |
# |    explained_variance   | 0.973         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.00232       |
# |    n_updates            | 460           |
# |    policy_gradient_loss | -0.00129      |
# |    value_loss           | 0.000688      |
# -------------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 25        |
# |    ep_rew_mean          | -1.62     |
# | time/                   |           |
# |    fps                  | 386       |
# |    iterations           | 48        |
# |    time_elapsed         | 254       |
# |    total_timesteps      | 98304     |
# | train/                  |           |
# |    approx_kl            | 2.0740092 |
# |    clip_fraction        | 0.141     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.00653  |
# |    explained_variance   | 0.998     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0509   |
# |    n_updates            | 470       |
# |    policy_gradient_loss | -0.0411   |
# |    value_loss           | 0.000246  |
# ---------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 44       |
# |    ep_rew_mean          | -3.74    |
# | time/                   |          |
# |    fps                  | 387      |
# |    iterations           | 49       |
# |    time_elapsed         | 259      |
# |    total_timesteps      | 100352   |
# | train/                  |          |
# |    approx_kl            | 0.0      |
# |    clip_fraction        | 0        |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -0.00044 |
# |    explained_variance   | 0.0121   |
# |    learning_rate        | 0.0003   |
# |    loss                 | 0.0604   |
# |    n_updates            | 480      |
# |    policy_gradient_loss | 4e-08    |
# |    value_loss           | 0.219    |
# --------------------------------------
